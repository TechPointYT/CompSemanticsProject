# %%
from collections import Counter
import os
import pickle

cent19words = []
cent20words = []

def txt_to_counts(tfile):
    
    words = []
    with open(tfile, "r+") as f:
        f.readline()
        for line in f:
            info = line.split()
            words.append(info[1])
            # went with lemma instead of actual word because the lemmas were already stripped for upper/lowercase
    counts = Counter(words)
    return counts



rootdir19 = 'C:\\Users\\David\Desktop\\CompSemanticsProject\\text_files_centuries\\19th_century'
century_counts = Counter()
cur_c = 0
past_year=0
years = []

for subdir in os.listdir(rootdir19):
    #yield subdir, dirs, files
    
    for file in os.listdir(rootdir19+"\\"+subdir):     
        #print(file)
        #print(os.path.join(rootdir19+"\\"+subdir+"\\"+file))
        past_year = year
        curr_counts = txt_to_counts(os.path.join(rootdir19+"\\"+subdir+"\\"+file)) 
        year = file.split("_")
        year = year[1] 
        if past_year == year:
            cur_c += 1
        else:
            cur_c = 0
            past_year
        years.append(int(year)+(cur_c/100.0))
        century_counts["whom"+"_"+year+"_"+str(cur_c) ] =  curr_counts["whom"]
        century_counts["who"+"_"+year+"_"+str(cur_c) ] =  curr_counts["who"]
print(century_counts)
# Out:
# Counter({'contract_1881_5': 13255, 'contract_1897_0': 10004, 'contract_1876_2': 9920, 'contract_1886_7': 7110, 'contract_1899_15': 5742, 'contract_1895_14': 5696, 'contract_1855_1': 5655, 'contract_1869_29': 5467, 'contract_1869_7': 4704, 'contract_1880_4': 4441, 'contract_1887_25': 3966, 'contract_1882_2': 3845, 'contract_1852_2': 3827, 'contract_1848_2': 3797, 'contract_1897_4': 3771, 'contract_1886_0': 3654, 'contract_1849_1': 3517, 'contract_1866_21': 3511, 'contract_1852_7': 3508, 'contract_1884_4': 3489, 'contract_1892_9': 3291, 'contract_1890_2': 3164, 'contract_1856_22': 3083, 'contract_1877_9': 3063, 'contract_1865_10': 2936, 'contract_1899_11': 2933, 'contract_1899_20': 2897, 'contract_1884_12': 2836, 'contract_1875_4': 2813, 'contract_1863_0': 2792, 'contract_1854_14': 2717, 'contract_1892_18': 2692, 'contract_1876_1': 2434, 'contract_1884_16': 2433, 'contract_1894_6': 2433, 'contract_1890_5': 2410, 'contract_1894_1': 2376, 'contract_1834_5': 2347, 'contract_1882_9': 2289,
# ...

# %%
import pandas as pd
import numpy as np
from collections import Counter
years = {}
past_year = 0
feature_count_df = pd.DataFrame([])
for yer in century_counts:
    
    year = str(yer.split("_")[1])
    #print(type(year))
    
    if year not in years:
        years[year]= {}
        if "whom" in yer:    
            years[year]["whom"] = century_counts[yer]
        elif "who" in yer:
            years[year]["who"] = century_counts[yer]
    else:
        if "whom" in yer: 
            years[str(year)]["whom"] = years[str(year)]["whom"]+ century_counts[yer]
        elif "who" in yer:
            years[str(year)]["who"] = years[str(year)]["who"]+ century_counts[yer]
print(years)       
#feature_count_df = pd.DataFrame({"year": years[]} )
#feature_count_df.set_index(["year","whom"])
#feature_count_df["cent"] = ["19th" for num in range(len(feature_count_df.year))]
#feature_count_df.head()



#%matplotlib inline
#plot = feature_count_df.plot( x = "years" , y = "whom" )
# Out:
# {'1810': {'whom': 30}, '1811': {'whom': 19}, '1812': {'whom': 53}, '1813': {'whom': 8}, '1814': {'whom': 21}, '1815': {'whom': 64}, '1817': {'whom': 11}, '1818': {'whom': 32}, '1819': {'whom': 57}, '1820': {'whom': 29}, '1821': {'whom': 30}, '1822': {'whom': 198}, '1823': {'whom': 678}, '1824': {'whom': 293}, '1825': {'whom': 57}, '1826': {'whom': 83}, '1827': {'whom': 1017}, '1828': {'whom': 155}, '1829': {'whom': 33}, '1830': {'whom': 164}, '1831': {'whom': 164}, '1832': {'whom': 162}, '1833': {'whom': 168}, '1834': {'whom': 453}, '1835': {'whom': 1104}, '1836': {'whom': 403}, '1837': {'whom': 220}, '1838': {'whom': 324}, '1839': {'whom': 1015}, '1840': {'whom': 306}, '1841': {'whom': 300}, '1842': {'whom': 237}, '1843': {'whom': 377}, '1844': {'whom': 271}, '1845': {'whom': 739}, '1846': {'whom': 664}, '1847': {'whom': 401}, '1848': {'whom': 661}, '1849': {'whom': 711}, '1850': {'whom': 365}, '1851': {'whom': 316}, '1852': {'whom': 377}, '1853': {'whom': 493}, '1854': {'whom': 577
# ...
